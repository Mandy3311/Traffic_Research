# %%
import osmnx as ox
import geopandas as gpd

# download
place_name = "Pennsylvania, USA"
G = ox.graph_from_place(place_name, network_type='drive')

# convert to a GeoDataFrame
gdf_edges = ox.graph_to_gdfs(G, nodes=False)
print(gdf_edges.head())
# Out:
# /Users/mandiliu/Desktop/US_Accidents/osmenv/lib/python3.12/site-packages/osmnx/_overpass.py:254: UserWarning: This area is 54 times your configured Overpass max query area size. It will automatically be divided up into multiple sub-queries accordingly. This may take a long time.
#   multi_poly_proj = utils_geo._consolidate_subdivide_geometry(poly_proj)
#                                                    osmid            name  \
# u        v        key
# 53448467 53584047 0                            549672418        Lay Road
# 53452578 53582089 0                              6756166  Lake View Road
# 53496150 53612694 0                              6733147    Orchard Road
#          53608642 0                            833253852    Orchard Road
#          53496211 0    [6672939, 1245422676, 1245422677]     Cooper Road
#
#                            highway oneway reversed   length  \
# u        v        key
# 53448467 53584047 0    residential  False     True  188.310
# 53452578 53582089 0    residential  False     True  183.839
# 53496150 53612694 0    residential  False     True  803.282
#          53608642 0    residential  False    False  408.870
#          53496211 0    residential  False    False  863.941
#
#                                                                 geometry  \
# u        v        key
# 53448467 53584047 0    LINESTRING (-76.27339 39.76654, -76.27378 39.7...
# 53452578 53582089 0    LINESTRING (-76.27907 39.76594, -76.27977 39.7...
# 53496150 53612694 0    LINESTRING (-76.27278 39.73138, -76.27348 39.7...
#          53608642 0    LINESTRING (-76.27278 39.73138, -76.27264 39.7...
#          53496211 0    LINESTRING (-76.27278 39.73138, -76.27167 39.7...
#
#                       bridge maxspeed lanes  ref tunnel access service  \
# u        v        key
# 53448467 53584047 0      NaN      NaN   NaN  NaN    NaN    NaN     NaN
# 53452578 53582089 0      NaN      NaN   NaN  NaN    NaN    NaN     NaN
# 53496150 53612694 0      NaN      NaN   NaN  NaN    NaN    NaN     NaN
#          53608642 0      NaN      NaN   NaN  NaN    NaN    NaN     NaN
#          53496211 0      yes      NaN   NaN  NaN    NaN    NaN     NaN
#
#                       junction width area
# u        v        key
# 53448467 53584047 0        NaN   NaN  NaN
# 53452578 53582089 0        NaN   NaN  NaN
# 53496150 53612694 0        NaN   NaN  NaN
#          53608642 0        NaN   NaN  NaN
#          53496211 0        NaN   NaN  NaN

# %%
print(gdf_edges.dtypes)
# Out:
# osmid         object
# name          object
# highway       object
# oneway        object
# reversed      object
# length       float64
# geometry    geometry
# bridge        object
# maxspeed      object
# lanes         object
# ref           object
# tunnel        object
# access        object
# service       object
# junction      object
# width         object
# area          object
# dtype: object

# %%
# Ensure all object columns contain only strings
for column in gdf_edges.select_dtypes(include=['object']).columns:
    gdf_edges[column] = gdf_edges[column].astype(str)

# %%
# Save edges to a Shapefile(for arcgis)
# gdf_edges.to_file("output/pennsylvania_roads.shp")

# %%
from shapely.geometry import LineString, MultiLineString

# Extract lat/lng for each road segment
road_segments = []

for index, row in gdf_edges.iterrows():
    if isinstance(row.geometry, LineString):
        coords = list(row.geometry.coords)
    elif isinstance(row.geometry, MultiLineString):
        coords = [list(line.coords) for line in row.geometry]
    road_segments.append({'id': row['osmid'], 'name': row['name'], 'coords': coords})

for segment in road_segments[:5]:
    print(segment)
# Out:
# {'id': '549672418', 'name': 'Lay Road', 'coords': [(-76.2733911, 39.7665376), (-76.2737825, 39.7666525), (-76.2741398, 39.7666703), (-76.2744317, 39.7666349), (-76.2747249, 39.7665602), (-76.2754428, 39.7662528)]}
# {'id': '6756166', 'name': 'Lake View Road', 'coords': [(-76.2790655, 39.7659438), (-76.2797657, 39.7659885), (-76.2799825, 39.7659865), (-76.2803705, 39.7658867), (-76.2807163, 39.7657747), (-76.2811049, 39.7656048)]}
# {'id': '6733147', 'name': 'Orchard Road', 'coords': [(-76.2727801, 39.7313838), (-76.273476, 39.731046), (-76.274404, 39.730693), (-76.2749359, 39.7304721), (-76.2751323, 39.7303906), (-76.275181, 39.730369), (-76.2759303, 39.7300465), (-76.276079, 39.7299747), (-76.2768931, 39.729547), (-76.2772635, 39.7293635), (-76.2778234, 39.7290533), (-76.2783629, 39.7287211), (-76.279117, 39.7281207), (-76.2802862, 39.7271465)]}
# {'id': '833253852', 'name': 'Orchard Road', 'coords': [(-76.2727801, 39.7313838), (-76.2726394, 39.7315704), (-76.272398, 39.7319995), (-76.2719168, 39.7328824), (-76.2718543, 39.7329737), (-76.2717977, 39.7330406), (-76.2716852, 39.7331405), (-76.2715559, 39.7332373), (-76.2713702, 39.7333694), (-76.2703426, 39.7341872), (-76.2701086, 39.7343619)]}
# {'id': '[6672939, 1245422676, 1245422677]', 'name': 'Cooper Road', 'coords': [(-76.2727801, 39.7313838), (-76.2716722, 39.7314611), (-76.2715158, 39.731469), (-76.2713958, 39.731463), (-76.2708064, 39.7313968), (-76.2707177, 39.7313936), (-76.2706434, 39.7313943), (-76.2705579, 39.7314048), (-76.2704469, 39.7314279), (-76.269544, 39.7317174), (-76.2693946, 39.731758), (-76.2692273, 39.7317952), (-76.2690769, 39.7318263), (-76.2689323, 39.7318486), (-76.2687514, 39.7318661), (-76.2685655, 39.731874), (-76.2679867, 39.7318668), (-76.2678507, 39.7318583), (-76.2677226, 39.7318458), (-76.2675763, 39.7318221), (-76.266963, 39.7316981), (-76.2668211, 39.7316639), (-76.2666809, 39.7316249), (-76.266541, 39.7315734), (-76.2664414, 39.7315258), (-76.2663554, 39.7314688), (-76.2662828, 39.7314105), (-76.2662101, 39.731324), (-76.2661627, 39.7312459), (-76.2661152, 39.7311548), (-76.2660724, 39.7310468), (-76.2659421, 39.7306413), (-76.2658997, 39.7305432), (-76.265856, 39.7304654), (-76.2658112, 39.7303991), (-76.2657596, 39.7303344), (-76.2656772, 39.7302405), (-76.2655999, 39.7301685), (-76.265224, 39.7298524), (-76.2651654, 39.7297951), (-76.2651163, 39.7297359), (-76.2650763, 39.7296723), (-76.2650496, 39.7296033), (-76.2650316, 39.7295314), (-76.2649974, 39.729349), (-76.2649841, 39.7293062), (-76.2649669, 39.7292694), (-76.2648578, 39.7291318)]}

# %%
import pandas as pd
df_road_segments = pd.DataFrame(road_segments)

# Combine coordinates with the same road name
def combine_coords(coord_list):
    combined = []
    for coords in coord_list:
        if isinstance(coords[0], list):  # Handle MultiLineString case
            combined.extend([item for sublist in coords for item in sublist])
        else:
            combined.extend(coords)
    return combined
combined_segments = df_road_segments.groupby('name')['coords'].apply(combine_coords).reset_index()

# %%
print(combined_segments.head())
# Out:
#                   name                                             coords
# 0         Hycrest Lane  [(-80.2028818, 40.7950576), (-80.2029258, 40.7...
# 1   10 Acres Wood Lane  [(-79.3113291, 40.1509223), (-79.3114132, 40.1...
# 2        10 Point Lane  [(-80.1286767, 40.6889168), (-80.1282986, 40.6...
# 3  10 Point Lodge Road  [(-75.8003135, 40.9816957), (-75.8016558, 40.9...
# 4       10 School Road  [(-79.3630866, 40.4248068), (-79.3612869, 40.4...

# %%
crash = pd.read_csv('output/crash_flag_cycle_roadway.csv')
crash.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11438 entries, 0 to 11437
# Data columns (total 92 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   CRN                             11438 non-null  int64
#  1   BELTED_DEATH_COUNT              11438 non-null  int64
#  2   BELTED_SUSP_SERIOUS_INJ_COUNT   11438 non-null  int64
#  3   COUNTY                          11438 non-null  int64
#  4   CRASH_MONTH                     11438 non-null  int64
#  5   CRASH_YEAR                      11438 non-null  int64
#  6   DAY_OF_WEEK                     11438 non-null  int64
#  7   DEC_LAT                         11438 non-null  float64
#  8   DEC_LONG                        11438 non-null  float64
#  9   FATAL_COUNT                     11438 non-null  int64
#  10  HOUR_OF_DAY                     11438 non-null  float64
#  11  ILLUMINATION                    11438 non-null  int64
#  12  INJURY_COUNT                    11438 non-null  int64
#  13  INTERSECT_TYPE                  11438 non-null  int64
#  14  LANE_CLOSED                     11438 non-null  int64
#  15  LOCATION_TYPE                   11438 non-null  int64
#  16  MAX_SEVERITY_LEVEL              11438 non-null  int64
#  17  MCYCLE_DEATH_COUNT              11438 non-null  int64
#  18  MCYCLE_SUSP_SERIOUS_INJ_COUNT   11438 non-null  int64
#  19  MOTORCYCLE_COUNT                11438 non-null  int64
#  20  MUNICIPALITY                    11438 non-null  int64
#  21  NONMOTR_COUNT                   11438 non-null  int64
#  22  NONMOTR_DEATH_COUNT             11438 non-null  int64
#  23  NONMOTR_SUSP_SERIOUS_INJ_COUNT  11438 non-null  int64
#  24  PED_COUNT                       11438 non-null  int64
#  25  PED_DEATH_COUNT                 11438 non-null  int64
#  26  PED_SUSP_SERIOUS_INJ_COUNT      11438 non-null  int64
#  27  PERSON_COUNT                    11438 non-null  int64
#  28  POSSIBLE_INJ_COUNT              11438 non-null  int64
#  29  RELATION_TO_ROAD                11438 non-null  int64
#  30  ROAD_CONDITION                  11438 non-null  int64
#  31  SECONDARY_CRASH                 11438 non-null  object
#  32  SUSP_MINOR_INJ_COUNT            11438 non-null  int64
#  33  SUSP_SERIOUS_INJ_COUNT          11438 non-null  int64
#  34  TOT_INJ_COUNT                   11438 non-null  int64
#  35  TOTAL_UNITS                     11438 non-null  int64
#  36  UNB_DEATH_COUNT                 11438 non-null  int64
#  37  UNB_SUSP_SERIOUS_INJ_COUNT      11438 non-null  int64
#  38  UNBELTED_OCC_COUNT              11438 non-null  int64
#  39  UNK_INJ_DEG_COUNT               11438 non-null  int64
#  40  UNK_INJ_PER_COUNT               11438 non-null  int64
#  41  URBAN_AREA                      11438 non-null  int64
#  42  URBAN_RURAL                     11438 non-null  int64
#  43  WEATHER1                        11438 non-null  int64
#  44  WORK_ZONE_IND                   11438 non-null  object
#  45  AGGRESSIVE_DRIVING              11438 non-null  float64
#  46  ALCOHOL_RELATED                 11438 non-null  float64
#  47  ANGLE_CRASH                     11438 non-null  float64
#  48  BACKUP_NONRECURRING             11438 non-null  float64
#  49  BACKUP_CONGESTION               11438 non-null  float64
#  50  BICYCLE                         11438 non-null  float64
#  51  CROSS_MEDIAN                    11438 non-null  float64
#  52  CURVE_DVR_ERROR                 11438 non-null  float64
#  53  CURVED_ROAD                     11438 non-null  float64
#  54  DEER_RELATED                    11438 non-null  float64
#  55  DISTRACTED                      11438 non-null  float64
#  56  DRINKING_DRIVER                 11438 non-null  float64
#  57  DRIVER_16YR                     11438 non-null  float64
#  58  DRIVER_17YR                     11438 non-null  float64
#  59  DRIVER_18YR                     11438 non-null  float64
#  60  DRIVER_19YR                     11438 non-null  float64
#  61  DRIVER_20YR                     11438 non-null  float64
#  62  DRIVER_50_64YR                  11438 non-null  float64
#  63  DRIVER_65_74YR                  11438 non-null  float64
#  64  DRIVER_75PLUS                   11438 non-null  float64
#  65  DRUG_RELATED                    11438 non-null  float64
#  66  DRUGGED_DRIVER                  11438 non-null  float64
#  67  ICY_ROAD                        11438 non-null  float64
#  68  ILLUMINATION_DARK               11438 non-null  float64
#  69  INTERSECTION                    11438 non-null  float64
#  70  INTERSTATE                      11438 non-null  float64
#  71  LANE_DEPARTURE                  11438 non-null  float64
#  72  LEFT_TURN                       11438 non-null  float64
#  73  LIMIT_65MPH                     11438 non-null  float64
#  74  LIMIT_70MPH                     11438 non-null  float64
#  75  MARIJUANA_RELATED               11438 non-null  float64
#  76  RAMP                            11438 non-null  float64
#  77  RAMP_SEGMENT                    11438 non-null  float64
#  78  REAR_END                        11438 non-null  float64
#  79  ROUNDABOUT                      11438 non-null  float64
#  80  RUNNING_RED_LT                  11438 non-null  float64
#  81  RUNNING_STOP_SIGN               11438 non-null  float64
#  82  SPEEDING                        11438 non-null  float64
#  83  SPEEDING_RELATED                11438 non-null  float64
#  84  UNBELTED                        11438 non-null  float64
#  85  UNDERAGE_DRNK_DRV               11438 non-null  float64
#  86  VULNERABLE_ROAD_USER_FATAL      11438 non-null  float64
#  87  WET_ROAD                        11438 non-null  float64
#  88  WORK_ZONE                       11438 non-null  float64
#  89  YOUNG_DRIVER                    11438 non-null  float64
#  90  SPEED_LIMIT                     11438 non-null  float64
#  91  STREET_NAME                     11438 non-null  object
# dtypes: float64(49), int64(40), object(3)
# memory usage: 8.0+ MB

# %%
merged_data = crash.merge(combined_segments, left_on='STREET_NAME', right_on='name', how='left')
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11438 entries, 0 to 11437
# Data columns (total 94 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   CRN                             11438 non-null  int64
#  1   BELTED_DEATH_COUNT              11438 non-null  int64
#  2   BELTED_SUSP_SERIOUS_INJ_COUNT   11438 non-null  int64
#  3   COUNTY                          11438 non-null  int64
#  4   CRASH_MONTH                     11438 non-null  int64
#  5   CRASH_YEAR                      11438 non-null  int64
#  6   DAY_OF_WEEK                     11438 non-null  int64
#  7   DEC_LAT                         11438 non-null  float64
#  8   DEC_LONG                        11438 non-null  float64
#  9   FATAL_COUNT                     11438 non-null  int64
#  10  HOUR_OF_DAY                     11438 non-null  float64
#  11  ILLUMINATION                    11438 non-null  int64
#  12  INJURY_COUNT                    11438 non-null  int64
#  13  INTERSECT_TYPE                  11438 non-null  int64
#  14  LANE_CLOSED                     11438 non-null  int64
#  15  LOCATION_TYPE                   11438 non-null  int64
#  16  MAX_SEVERITY_LEVEL              11438 non-null  int64
#  17  MCYCLE_DEATH_COUNT              11438 non-null  int64
#  18  MCYCLE_SUSP_SERIOUS_INJ_COUNT   11438 non-null  int64
#  19  MOTORCYCLE_COUNT                11438 non-null  int64
#  20  MUNICIPALITY                    11438 non-null  int64
#  21  NONMOTR_COUNT                   11438 non-null  int64
#  22  NONMOTR_DEATH_COUNT             11438 non-null  int64
#  23  NONMOTR_SUSP_SERIOUS_INJ_COUNT  11438 non-null  int64
#  24  PED_COUNT                       11438 non-null  int64
#  25  PED_DEATH_COUNT                 11438 non-null  int64
#  26  PED_SUSP_SERIOUS_INJ_COUNT      11438 non-null  int64
#  27  PERSON_COUNT                    11438 non-null  int64
#  28  POSSIBLE_INJ_COUNT              11438 non-null  int64
#  29  RELATION_TO_ROAD                11438 non-null  int64
#  30  ROAD_CONDITION                  11438 non-null  int64
#  31  SECONDARY_CRASH                 11438 non-null  object
#  32  SUSP_MINOR_INJ_COUNT            11438 non-null  int64
#  33  SUSP_SERIOUS_INJ_COUNT          11438 non-null  int64
#  34  TOT_INJ_COUNT                   11438 non-null  int64
#  35  TOTAL_UNITS                     11438 non-null  int64
#  36  UNB_DEATH_COUNT                 11438 non-null  int64
#  37  UNB_SUSP_SERIOUS_INJ_COUNT      11438 non-null  int64
#  38  UNBELTED_OCC_COUNT              11438 non-null  int64
#  39  UNK_INJ_DEG_COUNT               11438 non-null  int64
#  40  UNK_INJ_PER_COUNT               11438 non-null  int64
#  41  URBAN_AREA                      11438 non-null  int64
#  42  URBAN_RURAL                     11438 non-null  int64
#  43  WEATHER1                        11438 non-null  int64
#  44  WORK_ZONE_IND                   11438 non-null  object
#  45  AGGRESSIVE_DRIVING              11438 non-null  float64
#  46  ALCOHOL_RELATED                 11438 non-null  float64
#  47  ANGLE_CRASH                     11438 non-null  float64
#  48  BACKUP_NONRECURRING             11438 non-null  float64
#  49  BACKUP_CONGESTION               11438 non-null  float64
#  50  BICYCLE                         11438 non-null  float64
#  51  CROSS_MEDIAN                    11438 non-null  float64
#  52  CURVE_DVR_ERROR                 11438 non-null  float64
#  53  CURVED_ROAD                     11438 non-null  float64
#  54  DEER_RELATED                    11438 non-null  float64
#  55  DISTRACTED                      11438 non-null  float64
#  56  DRINKING_DRIVER                 11438 non-null  float64
#  57  DRIVER_16YR                     11438 non-null  float64
#  58  DRIVER_17YR                     11438 non-null  float64
#  59  DRIVER_18YR                     11438 non-null  float64
#  60  DRIVER_19YR                     11438 non-null  float64
#  61  DRIVER_20YR                     11438 non-null  float64
#  62  DRIVER_50_64YR                  11438 non-null  float64
#  63  DRIVER_65_74YR                  11438 non-null  float64
#  64  DRIVER_75PLUS                   11438 non-null  float64
#  65  DRUG_RELATED                    11438 non-null  float64
#  66  DRUGGED_DRIVER                  11438 non-null  float64
#  67  ICY_ROAD                        11438 non-null  float64
#  68  ILLUMINATION_DARK               11438 non-null  float64
#  69  INTERSECTION                    11438 non-null  float64
#  70  INTERSTATE                      11438 non-null  float64
#  71  LANE_DEPARTURE                  11438 non-null  float64
#  72  LEFT_TURN                       11438 non-null  float64
#  73  LIMIT_65MPH                     11438 non-null  float64
#  74  LIMIT_70MPH                     11438 non-null  float64
#  75  MARIJUANA_RELATED               11438 non-null  float64
#  76  RAMP                            11438 non-null  float64
#  77  RAMP_SEGMENT                    11438 non-null  float64
#  78  REAR_END                        11438 non-null  float64
#  79  ROUNDABOUT                      11438 non-null  float64
#  80  RUNNING_RED_LT                  11438 non-null  float64
#  81  RUNNING_STOP_SIGN               11438 non-null  float64
#  82  SPEEDING                        11438 non-null  float64
#  83  SPEEDING_RELATED                11438 non-null  float64
#  84  UNBELTED                        11438 non-null  float64
#  85  UNDERAGE_DRNK_DRV               11438 non-null  float64
#  86  VULNERABLE_ROAD_USER_FATAL      11438 non-null  float64
#  87  WET_ROAD                        11438 non-null  float64
#  88  WORK_ZONE                       11438 non-null  float64
#  89  YOUNG_DRIVER                    11438 non-null  float64
#  90  SPEED_LIMIT                     11438 non-null  float64
#  91  STREET_NAME                     11438 non-null  object
#  92  name                            0 non-null      object
#  93  coords                          0 non-null      object
# dtypes: float64(49), int64(40), object(5)
# memory usage: 8.2+ MB
